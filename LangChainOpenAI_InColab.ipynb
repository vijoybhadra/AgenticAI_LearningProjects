# %%
# !pip install -U langchain-openai langchain-core python-dotenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.6/84.6 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 476.0/476.0 kB 11.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.1.3
#     Uninstalling langchain-core-1.1.3:
#       Successfully uninstalled langchain-core-1.1.3
# ...

# %%
import os
os.environ["OPENAI_API_KEY"] = "YOUR OPENAI API KEY GOES HERE"

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.output_parsers import StrOutputParser
from langchain_core.chat_history import InMemoryChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

# 1. Initialize OpenAI LLM
llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.3
)

# 2. Prompt with memory placeholder
prompt = ChatPromptTemplate.from_messages([
    ("system",
     "You are a concise study buddy. "
     "Explain clearly. If code is requested, give minimal runnable examples."),
    MessagesPlaceholder(variable_name="history"),
    ("human", "{input}")
])

# 3. Build the chain
chain = prompt | llm | StrOutputParser()

# 4. In-memory chat history
store = {}

def get_history(session_id: str):
    if session_id not in store:
        store[session_id] = InMemoryChatMessageHistory()
    return store[session_id]

chat = RunnableWithMessageHistory(
    chain,
    get_history,
    input_messages_key="input",
    history_messages_key="history"
)

print("✅ Study Buddy ready!")
# Out:
# ✅ Study Buddy ready!
